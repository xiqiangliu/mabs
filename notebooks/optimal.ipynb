# %%
import seaborn as sns
from pathlib import Path

import mabs

sns.set_theme()

# %%
mabs.visualization.plot_mean(
    Path("../results/optimal/bernoulli.pkl").resolve(),
    group_name="prior",
    x_axis="p",
)

# %%
mabs.visualization.plot_var(
    Path("../results/optimal/bernoulli.pkl").resolve(),
    group_name="prior",
    x_axis="p",
)
